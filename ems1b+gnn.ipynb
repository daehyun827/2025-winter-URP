# %% [markdown]
# <a href="https://colab.research.google.com/github/daehyun827/2025-winter-URP/blob/GNN/ems1b%2Bgnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2023312038 겨울 URP 단백질 4종류(Soluble, Lipid Anchor, Peripheral, Transmembrane)분류 모델
#
# 기본 구조
#
# PLM(ESM1b_t33_650M_UR50S) -> Amino acid embedding & Attention map(Contact map) -> GNN(구조예측) -> 구조를 통한 단백질의 특징 추출 -> 단백질 분류
#
# 이런 구조를 정한 이유
# Protein MPNN에서 입력과 출력을 반대로 만든 모델이라고도 볼 수 있음. Prot-Trans 논문에서 PLM의 마지막 hiddeen layer의 embedding에서 서열만으로 학습을 시켜도 구조정보와 아미노산의 특징을 제대로 반영할 수 있음을 보여줬음. 그렇기에, Embedding으로 얻은 구조 정보를 통해서 서열을 받았을 때 이를 다시 구조로 변환시켜, 단백질 외부 특징을 뽑아낼 수 있다면, 위 단백질들을 분류할 수 있지 않을까라는 생각에서 이런 아키텍처로 구성하게 되었음.
# 여러 종류의 PLM에서 ESM을 선택한 이유는, ESM의 경우 아미노산 간의 contact map을 제공하지만, Prot-Trans의 경우 이를 제공하지는 않아 hidden layer에서 attention map을 추출하여 가공해야하는 번거로움이 있어 일단 ESM1b_t33_650M_UR50S을 사용하게 되었음
#
# * 참고내용1 :
# GNN의 경우 서열을 그래프 형태(노드와 엣지(간선))으로 봐야하기에 이를 정의해야하는 문제가 있었음. 엣지의 경우 아미노산 간의 위치 관계를 나타내는 contact map을 사용하였고, 노드의 경우 input 서열에 해당하는 아미노산 embedding을 사용하였음
#
# * 참고내용2 :
# Prot-Trans 논문에서는 2차구조를 예측할 때 2 layer CNN을 달아서 구조를 예측했다고 나오는데, 시간이 남는다면 CNN으로 구조를 예측하여 단백질의 특징을 뽑고 분류하였을때 결과 차이가 날 지 보는 것도 좋을듯함.
#
# * 참고내용3:
# 앞서, Prot-Trans의 경우 attention map을 가공해야되서 ESM을 사용했다고 하는데, Prot-Trans(그 중 큰 모델인 Prot-T5) 모델 중 ESM보다 더 좋은 embedding을 제공하는 경우도 있으므로, 시간이 된다면 Prot-Trans 버전으로도 만들어보면 좋을 것 같음.
#
# * 참고내용4:
# 코랩에서 DeepLoc 데이터를 on fly로 가공해서 하려다보니, GPU 메모리 부족 문제가 발생해서 데이터를 100개의 단백질마다 끊어서 저장한 뒤, 이 데이터로 Training과 Validation을 진행했음. 혹시, 코딩을 잘 한다면 이 문제를 해결해주길 바람 ㅎㅎ

# %%
# !pip -q install transformers torch_geometric tqdm scikit-learn

import torch
print("CUDA:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA: True
# GPU: Tesla T4

# %%
import os, math, glob
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader as GraphDataLoader
from torch_geometric.nn import EdgeConv, global_add_pool
from transformers import EsmModel, EsmTokenizer
from tqdm import tqdm

# ===== 1) GNN 모델 =====
class ProteinGNN(nn.Module):
    def __init__(self, input_dim=1280, hidden_dim=256, num_layers=4, num_classes=4):
        super().__init__()
        self.input_proj = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.ReLU()
        )
        self.edge_mlps = nn.ModuleList([
            nn.Sequential(
                nn.Linear(2 * hidden_dim, hidden_dim),
                nn.ReLU(),
                nn.Linear(hidden_dim, hidden_dim)
            ) for _ in range(num_layers)
        ])
        self.residuals = nn.ModuleList([
            nn.Linear(hidden_dim, hidden_dim) if i == 0 else nn.Identity()
            for i in range(num_layers)
        ])
        self.gate_scorer = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim // 4),
            nn.ReLU(),
            nn.Linear(hidden_dim // 4, 1),
            nn.Sigmoid()
        )
        self.classifier = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim // 2),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(hidden_dim // 2, num_classes)
        )

    def forward(self, x_esm, edge_index, batch):
        x = self.input_proj(x_esm)
        for mlp, res in zip(self.edge_mlps, self.residuals):
            edge_out = EdgeConv(mlp, aggr='max')(x, edge_index)
            x = F.relu(edge_out + res(x))
        scores = self.gate_scorer(x).squeeze(-1)
        x_weighted = x * scores.unsqueeze(-1)
        graph_vec = global_add_pool(x_weighted, batch)
        logits = self.classifier(graph_vec)
        return logits, scores


# ===== 2) 데이터 로드/전처리 =====
def load_and_preprocess_data(csv_path):
    df = pd.read_csv(csv_path)
    df = df.drop(['Unnamed: 0'], axis=1, errors='ignore')

    label_cols = ['Peripheral', 'Transmembrane', 'LipidAnchor', 'Soluble']
    df['label'] = df[label_cols].idxmax(axis=1).map({
        'Peripheral': 0, 'Transmembrane': 1, 'LipidAnchor': 2, 'Soluble': 3
    }).astype(int)

    train_df = df[df['Partition'] <= 2].copy()
    val_df   = df[df['Partition'] > 2].copy()

    train_df = train_df[(train_df['Sequence'].str.len() >= 100) & (train_df['Sequence'].str.len() <= 800)]
    val_df   = val_df[(val_df['Sequence'].str.len() >= 100) & (val_df['Sequence'].str.len() <= 800)]

    print(f"Train: {len(train_df)}, Val: {len(val_df)}")
    return train_df.reset_index(drop=True), val_df.reset_index(drop=True)


# ===== 3) 평가 함수 =====
def evaluate(model, loader, device):
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for batch in loader:
            batch = batch.to(device)
            logits, _ = model(batch.x, batch.edge_index, batch.batch)
            pred = logits.argmax(dim=1)
            correct += (pred == batch.y).sum().item()
            total += batch.num_graphs
    return correct / total


# ===== 4) (핵심) ESM→그래프 저장 =====
def precompute_and_save_onefile(df, split_name, esm_model, tokenizer, device,
                                out_dir="/content/graphs", prob_threshold=0.6,
                                save_x_dtype=torch.float16):
    """
    split_name_graphs.pt 하나로 저장 (DB/청크 없이)
    - A100 추천: autocast(bf16)
    - attn은 GPU에서 edge만 뽑고 edge_index만 CPU로 내려서 속도/메모리 개선
    - x는 fp16으로 저장해서 파일 용량 절감
    """
    os.makedirs(out_dir, exist_ok=True)

    esm_model.eval()
    esm_model.config.output_attentions = True
    esm_model.config.return_dict = True

    graphs = []
    n = len(df)

    for i in tqdm(range(n), desc=f"Precompute {split_name}"):
        row = df.iloc[i]
        seq = row["Sequence"]
        label = int(row["label"])

        inputs = tokenizer(seq, return_tensors="pt", truncation=True, max_length=1022)
        inputs = {k: v.to(device) for k, v in inputs.items()}

        with torch.inference_mode():
            if device.startswith("cuda"):
              with torch.autocast("cuda", dtype=torch.bfloat16):
                  outputs = esm_model(**inputs, output_attentions=True, return_dict=True)
            else:
                outputs = esm_model(**inputs, output_attentions=True, return_dict=True)

            # node embedding (저장은 fp16로)
            x = outputs.last_hidden_state[0, 1:-1, :].detach().to(save_x_dtype).cpu()

            # ★ attn은 GPU에 두고 edge만 추출 후 edge_index만 CPU로
            attn = outputs.attentions[-1].mean(dim=1)[0, 1:-1, 1:-1]
            row_idx, col_idx = torch.where(attn > prob_threshold)
            valid = row_idx != col_idx
            edge_index = torch.stack([row_idx[valid], col_idx[valid]], dim=0).detach().cpu()

        graphs.append(Data(x=x, edge_index=edge_index, y=torch.tensor(label, dtype=torch.long)))

        # 정리
        del outputs, inputs, attn
        if device.startswith("cuda") and (i % 200 == 0):
            torch.cuda.empty_cache()

        if i % 100 == 0:
            print(f"[{split_name}] {i+1}/{n}")

    save_path = os.path.join(out_dir, f"{split_name}_graphs.pt")
    torch.save(graphs, save_path)
    print(f"✅ saved: {save_path} ({len(graphs)} graphs)")


# ===== (너 파일 경로만 여기서 맞춰주면 됨) =====
CSV_PATH = "/content/Swissprot_Membrane_Train_Validation_dataset.csv"
train_df, val_df = load_and_preprocess_data(CSV_PATH)
# Out:
# Train: 12571, Val: 8831

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)

# ESM 로드 (OOM 방지 위해 eager)
model_name = "facebook/esm1b_t33_650M_UR50S"
tokenizer = EsmTokenizer.from_pretrained(model_name)
esm_model = EsmModel.from_pretrained(model_name, attn_implementation="eager").to(device).eval()

# (선택) fp16으로 더 가볍게
# esm_model = esm_model.half()

THRESH = 0.6
OUT_DIR = "/content/graphs"

precompute_and_save_onefile(train_df, "train", esm_model, tokenizer, device,
                           out_dir=OUT_DIR, prob_threshold=THRESH)

precompute_and_save_onefile(val_df, "val", esm_model, tokenizer, device,
                           out_dir=OUT_DIR, prob_threshold=THRESH)
# Out:
# Using device: cuda
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Some weights of EsmModel were not initialized from the model checkpoint at facebook/esm1b_t33_650M_UR50S and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [train] chunk 1/126  sample 1/12571
# [train] chunk 1/126  sample 11/12571
# [train] chunk 1/126  sample 21/12571
# [train] chunk 1/126  sample 31/12571
# [train] chunk 1/126  sample 41/12571
# [train] chunk 1/126  sample 51/12571
# [train] chunk 1/126  sample 61/12571
# [train] chunk 1/126  sample 71/12571
# [train] chunk 1/126  sample 81/12571
# [train] chunk 1/126  sample 91/12571
# ✅ saved: /content/graphs/train_chunk0000.pt (100 graphs)
# [train] chunk 2/126  sample 101/12571
# [train] chunk 2/126  sample 111/12571
# [train] chunk 2/126  sample 121/12571
# [train] chunk 2/126  sample 131/12571
# [train] chunk 2/126  sample 141/12571
# [train] chunk 2/126  sample 151/12571
# [train] chunk 2/126  sample 161/12571
# [train] chunk 2/126  sample 171/12571
# [train] chunk 2/126  sample 181/12571
# [train] chunk 2/126  sample 191/12571
# ✅ saved: /content/graphs/train_chunk0001.pt (100 graphs)
# [train] chunk 3/126  sample 201/12571
# [train] chunk 3/126  sample 211/12571
# [train] chunk 3/126  sample 221/12571
# [train] chunk 3/126  sample 231/12571
# [train] chunk 3/126  sample 241/12571
# [train] chunk 3/126  sample 251/12571
# [train] chunk 3/126  sample 261/12571
# [train] chunk 3/126  sample 271/12571
# [train] chunk 3/126  sample 281/12571
# [train] chunk 3/126  sample 291/12571
# ✅ saved: /content/graphs/train_chunk0002.pt (100 graphs)
# [train] chunk 4/126  sample 301/12571
# [train] chunk 4/126  sample 311/12571
# [train] chunk 4/126  sample 321/12571
# [train] chunk 4/126  sample 331/12571
# [train] chunk 4/126  sample 341/12571
# [train] chunk 4/126  sample 351/12571
# [train] chunk 4/126  sample 361/12571
# [train] chunk 4/126  sample 371/12571
# [train] chunk 4/126  sample 381/12571
# [train] chunk 4/126  sample 391/12571
# ✅ saved: /content/graphs/train_chunk0003.pt (100 graphs)
# [train] chunk 5/126  sample 401/12571
# [train] chunk 5/126  sample 411/12571
# [train] chunk 5/126  sample 421/12571
# [train] chunk 5/126  sample 431/12571
# [train] chunk 5/126  sample 441/12571
# [train] chunk 5/126  sample 451/12571
# [train] chunk 5/126  sample 461/12571
# [train] chunk 5/126  sample 471/12571
# [train] chunk 5/126  sample 481/12571
# [train] chunk 5/126  sample 491/12571
# ✅ saved: /content/graphs/train_chunk0004.pt (100 graphs)
# [train] chunk 6/126  sample 501/12571
# [train] chunk 6/126  sample 511/12571
# [train] chunk 6/126  sample 521/12571
# [train] chunk 6/126  sample 531/12571
# [train] chunk 6/126  sample 541/12571
# [train] chunk 6/126  sample 551/12571
# [train] chunk 6/126  sample 561/12571
# [train] chunk 6/126  sample 571/12571
# [train] chunk 6/126  sample 581/12571
# [train] chunk 6/126  sample 591/12571
# ✅ saved: /content/graphs/train_chunk0005.pt (100 graphs)
# [train] chunk 7/126  sample 601/12571
# [train] chunk 7/126  sample 611/12571
# [train] chunk 7/126  sample 621/12571
# [train] chunk 7/126  sample 631/12571
# [train] chunk 7/126  sample 641/12571
# [train] chunk 7/126  sample 651/12571
# [train] chunk 7/126  sample 661/12571
# [train] chunk 7/126  sample 671/12571
# [train] chunk 7/126  sample 681/12571
# [train] chunk 7/126  sample 691/12571
# ✅ saved: /content/graphs/train_chunk0006.pt (100 graphs)
# [train] chunk 8/126  sample 701/12571
# [train] chunk 8/126  sample 711/12571
# [train] chunk 8/126  sample 721/12571
# [train] chunk 8/126  sample 731/12571
# [train] chunk 8/126  sample 741/12571
# [train] chunk 8/126  sample 751/12571
# [train] chunk 8/126  sample 761/12571
# [train] chunk 8/126  sample 771/12571
# [train] chunk 8/126  sample 781/12571
# [train] chunk 8/126  sample 791/12571
# ✅ saved: /content/graphs/train_chunk0007.pt (100 graphs)
# [train] chunk 9/126  sample 801/12571
# [train] chunk 9/126  sample 811/12571
# [train] chunk 9/126  sample 821/12571
# [train] chunk 9/126  sample 831/12571
# [train] chunk 9/126  sample 841/12571
# [train] chunk 9/126  sample 851/12571
# [train] chunk 9/126  sample 861/12571
# [train] chunk 9/126  sample 871/12571
# [train] chunk 9/126  sample 881/12571
# [train] chunk 9/126  sample 891/12571
# ✅ saved: /content/graphs/train_chunk0008.pt (100 graphs)
# [train] chunk 10/126  sample 901/12571
# [train] chunk 10/126  sample 911/12571
# [train] chunk 10/126  sample 921/12571
# [train] chunk 10/126  sample 931/12571
# [train] chunk 10/126  sample 941/12571
# [train] chunk 10/126  sample 951/12571
# [train] chunk 10/126  sample 961/12571
# [train] chunk 10/126  sample 971/12571
# [train] chunk 10/126  sample 981/12571
# [train] chunk 10/126  sample 991/12571
# ✅ saved: /content/graphs/train_chunk0009.pt (100 graphs)
# [train] chunk 11/126  sample 1001/12571
# [train] chunk 11/126  sample 1011/12571
# [train] chunk 11/126  sample 1021/12571
# [train] chunk 11/126  sample 1031/12571
# [train] chunk 11/126  sample 1041/12571
# [train] chunk 11/126  sample 1051/12571
# [train] chunk 11/126  sample 1061/12571
# [train] chunk 11/126  sample 1071/12571
# [train] chunk 11/126  sample 1081/12571
# [train] chunk 11/126  sample 1091/12571
# ✅ saved: /content/graphs/train_chunk0010.pt (100 graphs)
# [train] chunk 12/126  sample 1101/12571
# [train] chunk 12/126  sample 1111/12571
# [train] chunk 12/126  sample 1121/12571
# [train] chunk 12/126  sample 1131/12571
# [train] chunk 12/126  sample 1141/12571
# [train] chunk 12/126  sample 1151/12571
# [train] chunk 12/126  sample 1161/12571
# [train] chunk 12/126  sample 1171/12571
# [train] chunk 12/126  sample 1181/12571
# [train] chunk 12/126  sample 1191/12571
# ✅ saved: /content/graphs/train_chunk0011.pt (100 graphs)
# [train] chunk 13/126  sample 1201/12571
# [train] chunk 13/126  sample 1211/12571
# [train] chunk 13/126  sample 1221/12571
# [train] chunk 13/126  sample 1231/12571
# [train] chunk 13/126  sample 1241/12571
# [train] chunk 13/126  sample 1251/12571
# [train] chunk 13/126  sample 1261/12571
# [train] chunk 13/126  sample 1271/12571
# [train] chunk 13/126  sample 1281/12571
# [train] chunk 13/126  sample 1291/12571
# ✅ saved: /content/graphs/train_chunk0012.pt (100 graphs)
# [train] chunk 14/126  sample 1301/12571
# [train] chunk 14/126  sample 1311/12571
# [train] chunk 14/126  sample 1321/12571
# [train] chunk 14/126  sample 1331/12571
# [train] chunk 14/126  sample 1341/12571
# [train] chunk 14/126  sample 1351/12571
# [train] chunk 14/126  sample 1361/12571
# [train] chunk 14/126  sample 1371/12571
# [train] chunk 14/126  sample 1381/12571
# [train] chunk 14/126  sample 1391/12571
# ✅ saved: /content/graphs/train_chunk0013.pt (100 graphs)
# [train] chunk 15/126  sample 1401/12571
# [train] chunk 15/126  sample 1411/12571
# [train] chunk 15/126  sample 1421/12571
# [train] chunk 15/126  sample 1431/12571
# [train] chunk 15/126  sample 1441/12571
# [train] chunk 15/126  sample 1451/12571
# [train] chunk 15/126  sample 1461/12571
# [train] chunk 15/126  sample 1471/12571
# [train] chunk 15/126  sample 1481/12571
# [train] chunk 15/126  sample 1491/12571
# ✅ saved: /content/graphs/train_chunk0014.pt (100 graphs)
# [train] chunk 16/126  sample 1501/12571
# [train] chunk 16/126  sample 1511/12571
# [train] chunk 16/126  sample 1521/12571
# [train] chunk 16/126  sample 1531/12571
# [train] chunk 16/126  sample 1541/12571
# [train] chunk 16/126  sample 1551/12571
# [train] chunk 16/126  sample 1561/12571
# [train] chunk 16/126  sample 1571/12571
# [train] chunk 16/126  sample 1581/12571
# [train] chunk 16/126  sample 1591/12571
# ✅ saved: /content/graphs/train_chunk0015.pt (100 graphs)
# [train] chunk 17/126  sample 1601/12571
# [train] chunk 17/126  sample 1611/12571
# [train] chunk 17/126  sample 1621/12571
# [train] chunk 17/126  sample 1631/12571
# [train] chunk 17/126  sample 1641/12571
# [train] chunk 17/126  sample 1651/12571
# [train] chunk 17/126  sample 1661/12571
# [train] chunk 17/126  sample 1671/12571
# [train] chunk 17/126  sample 1681/12571
# [train] chunk 17/126  sample 1691/12571
# ✅ saved: /content/graphs/train_chunk0016.pt (100 graphs)
# [train] chunk 18/126  sample 1701/12571
# [train] chunk 18/126  sample 1711/12571
# [train] chunk 18/126  sample 1721/12571
# [train] chunk 18/126  sample 1731/12571
# [train] chunk 18/126  sample 1741/12571
# [train] chunk 18/126  sample 1751/12571
# [train] chunk 18/126  sample 1761/12571
# [train] chunk 18/126  sample 1771/12571
# [train] chunk 18/126  sample 1781/12571
# [train] chunk 18/126  sample 1791/12571
# ✅ saved: /content/graphs/train_chunk0017.pt (100 graphs)
# [train] chunk 19/126  sample 1801/12571
# [train] chunk 19/126  sample 1811/12571
# [train] chunk 19/126  sample 1821/12571
# [train] chunk 19/126  sample 1831/12571
# [train] chunk 19/126  sample 1841/12571
# [train] chunk 19/126  sample 1851/12571
# [train] chunk 19/126  sample 1861/12571
# [train] chunk 19/126  sample 1871/12571
# [train] chunk 19/126  sample 1881/12571
# [train] chunk 19/126  sample 1891/12571
# ✅ saved: /content/graphs/train_chunk0018.pt (100 graphs)
# [train] chunk 20/126  sample 1901/12571
# [train] chunk 20/126  sample 1911/12571
# [train] chunk 20/126  sample 1921/12571
# [train] chunk 20/126  sample 1931/12571
# [train] chunk 20/126  sample 1941/12571
# [train] chunk 20/126  sample 1951/12571
# [train] chunk 20/126  sample 1961/12571
# [train] chunk 20/126  sample 1971/12571
# [train] chunk 20/126  sample 1981/12571
# [train] chunk 20/126  sample 1991/12571
# ✅ saved: /content/graphs/train_chunk0019.pt (100 graphs)
# [train] chunk 21/126  sample 2001/12571
# [train] chunk 21/126  sample 2011/12571
# [train] chunk 21/126  sample 2021/12571
# [train] chunk 21/126  sample 2031/12571
# [train] chunk 21/126  sample 2041/12571
# [train] chunk 21/126  sample 2051/12571
# [train] chunk 21/126  sample 2061/12571
# [train] chunk 21/126  sample 2071/12571
# [train] chunk 21/126  sample 2081/12571
# [train] chunk 21/126  sample 2091/12571
# ✅ saved: /content/graphs/train_chunk0020.pt (100 graphs)
# [train] chunk 22/126  sample 2101/12571
# [train] chunk 22/126  sample 2111/12571
# [train] chunk 22/126  sample 2121/12571
# [train] chunk 22/126  sample 2131/12571
# [train] chunk 22/126  sample 2141/12571
# [train] chunk 22/126  sample 2151/12571
# [train] chunk 22/126  sample 2161/12571
# [train] chunk 22/126  sample 2171/12571
# [train] chunk 22/126  sample 2181/12571
# [train] chunk 22/126  sample 2191/12571
# ✅ saved: /content/graphs/train_chunk0021.pt (100 graphs)
# [train] chunk 23/126  sample 2201/12571
# [train] chunk 23/126  sample 2211/12571
# [train] chunk 23/126  sample 2221/12571
# [train] chunk 23/126  sample 2231/12571
# [train] chunk 23/126  sample 2241/12571
# [train] chunk 23/126  sample 2251/12571
# [train] chunk 23/126  sample 2261/12571
# [train] chunk 23/126  sample 2271/12571
# [train] chunk 23/126  sample 2281/12571
# [train] chunk 23/126  sample 2291/12571
# ✅ saved: /content/graphs/train_chunk0022.pt (100 graphs)
# [train] chunk 24/126  sample 2301/12571
# [train] chunk 24/126  sample 2311/12571
# [train] chunk 24/126  sample 2321/12571
# [train] chunk 24/126  sample 2331/12571
# [train] chunk 24/126  sample 2341/12571
# [train] chunk 24/126  sample 2351/12571
# [train] chunk 24/126  sample 2361/12571
# [train] chunk 24/126  sample 2371/12571
# [train] chunk 24/126  sample 2381/12571
# [train] chunk 24/126  sample 2391/12571
# ✅ saved: /content/graphs/train_chunk0023.pt (100 graphs)
# [train] chunk 25/126  sample 2401/12571
# [train] chunk 25/126  sample 2411/12571
# [train] chunk 25/126  sample 2421/12571
# [train] chunk 25/126  sample 2431/12571
# [train] chunk 25/126  sample 2441/12571
# [train] chunk 25/126  sample 2451/12571
# [train] chunk 25/126  sample 2461/12571
# [train] chunk 25/126  sample 2471/12571
# [train] chunk 25/126  sample 2481/12571
# [train] chunk 25/126  sample 2491/12571
# ✅ saved: /content/graphs/train_chunk0024.pt (100 graphs)
# [train] chunk 26/126  sample 2501/12571
# [train] chunk 26/126  sample 2511/12571
# [train] chunk 26/126  sample 2521/12571
# [train] chunk 26/126  sample 2531/12571
# [train] chunk 26/126  sample 2541/12571
# [train] chunk 26/126  sample 2551/12571
# [train] chunk 26/126  sample 2561/12571
# [train] chunk 26/126  sample 2571/12571
# [train] chunk 26/126  sample 2581/12571
# [train] chunk 26/126  sample 2591/12571
# ✅ saved: /content/graphs/train_chunk0025.pt (100 graphs)
# [train] chunk 27/126  sample 2601/12571
# [train] chunk 27/126  sample 2611/12571
# [train] chunk 27/126  sample 2621/12571
# [train] chunk 27/126  sample 2631/12571
# [train] chunk 27/126  sample 2641/12571
# [train] chunk 27/126  sample 2651/12571
# [train] chunk 27/126  sample 2661/12571
# [train] chunk 27/126  sample 2671/12571
# [train] chunk 27/126  sample 2681/12571
# [train] chunk 27/126  sample 2691/12571
# ✅ saved: /content/graphs/train_chunk0026.pt (100 graphs)
# [train] chunk 28/126  sample 2701/12571
# [train] chunk 28/126  sample 2711/12571
# [train] chunk 28/126  sample 2721/12571
# [train] chunk 28/126  sample 2731/12571
# [train] chunk 28/126  sample 2741/12571
# [train] chunk 28/126  sample 2751/12571
# [train] chunk 28/126  sample 2761/12571
# [train] chunk 28/126  sample 2771/12571
# [train] chunk 28/126  sample 2781/12571
# [train] chunk 28/126  sample 2791/12571
# ✅ saved: /content/graphs/train_chunk0027.pt (100 graphs)
# [train] chunk 29/126  sample 2801/12571
# [train] chunk 29/126  sample 2811/12571
# [train] chunk 29/126  sample 2821/12571
# [train] chunk 29/126  sample 2831/12571
# [train] chunk 29/126  sample 2841/12571
# [train] chunk 29/126  sample 2851/12571
# [train] chunk 29/126  sample 2861/12571
# [train] chunk 29/126  sample 2871/12571
# [train] chunk 29/126  sample 2881/12571
# [train] chunk 29/126  sample 2891/12571
# ✅ saved: /content/graphs/train_chunk0028.pt (100 graphs)
# [train] chunk 30/126  sample 2901/12571
# [train] chunk 30/126  sample 2911/12571
# [train] chunk 30/126  sample 2921/12571
# [train] chunk 30/126  sample 2931/12571
# [train] chunk 30/126  sample 2941/12571
# [train] chunk 30/126  sample 2951/12571
# [train] chunk 30/126  sample 2961/12571
# [train] chunk 30/126  sample 2971/12571
# [train] chunk 30/126  sample 2981/12571
# [train] chunk 30/126  sample 2991/12571
# ✅ saved: /content/graphs/train_chunk0029.pt (100 graphs)
# [train] chunk 31/126  sample 3001/12571
# [train] chunk 31/126  sample 3011/12571
# [train] chunk 31/126  sample 3021/12571
# [train] chunk 31/126  sample 3031/12571
# [train] chunk 31/126  sample 3041/12571
# [train] chunk 31/126  sample 3051/12571
# [train] chunk 31/126  sample 3061/12571
# [train] chunk 31/126  sample 3071/12571
# [train] chunk 31/126  sample 3081/12571
# [train] chunk 31/126  sample 3091/12571
# ✅ saved: /content/graphs/train_chunk0030.pt (100 graphs)
# [train] chunk 32/126  sample 3101/12571
# [train] chunk 32/126  sample 3111/12571
# [train] chunk 32/126  sample 3121/12571
# [train] chunk 32/126  sample 3131/12571
# [train] chunk 32/126  sample 3141/12571
# [train] chunk 32/126  sample 3151/12571
# [train] chunk 32/126  sample 3161/12571
# [train] chunk 32/126  sample 3171/12571
# [train] chunk 32/126  sample 3181/12571
# [train] chunk 32/126  sample 3191/12571
# ✅ saved: /content/graphs/train_chunk0031.pt (100 graphs)
# [train] chunk 33/126  sample 3201/12571
# [train] chunk 33/126  sample 3211/12571
# [train] chunk 33/126  sample 3221/12571
# [train] chunk 33/126  sample 3231/12571
# [train] chunk 33/126  sample 3241/12571
# [train] chunk 33/126  sample 3251/12571
# [train] chunk 33/126  sample 3261/12571
# [train] chunk 33/126  sample 3271/12571
# [train] chunk 33/126  sample 3281/12571
# [train] chunk 33/126  sample 3291/12571
# ✅ saved: /content/graphs/train_chunk0032.pt (100 graphs)
# [train] chunk 34/126  sample 3301/12571
# [train] chunk 34/126  sample 3311/12571
# [train] chunk 34/126  sample 3321/12571
# [train] chunk 34/126  sample 3331/12571
# [train] chunk 34/126  sample 3341/12571
# [train] chunk 34/126  sample 3351/12571
# [train] chunk 34/126  sample 3361/12571
# [train] chunk 34/126  sample 3371/12571
# [train] chunk 34/126  sample 3381/12571
# [train] chunk 34/126  sample 3391/12571
# ✅ saved: /content/graphs/train_chunk0033.pt (100 graphs)
# [train] chunk 35/126  sample 3401/12571
# [train] chunk 35/126  sample 3411/12571
# [train] chunk 35/126  sample 3421/12571
# [train] chunk 35/126  sample 3431/12571
# [train] chunk 35/126  sample 3441/12571
# [train] chunk 35/126  sample 3451/12571
# [train] chunk 35/126  sample 3461/12571
# [train] chunk 35/126  sample 3471/12571
# [train] chunk 35/126  sample 3481/12571
# [train] chunk 35/126  sample 3491/12571
# ✅ saved: /content/graphs/train_chunk0034.pt (100 graphs)
# [train] chunk 36/126  sample 3501/12571
# [train] chunk 36/126  sample 3511/12571
# [train] chunk 36/126  sample 3521/12571
# [train] chunk 36/126  sample 3531/12571
# [train] chunk 36/126  sample 3541/12571
# [train] chunk 36/126  sample 3551/12571
# [train] chunk 36/126  sample 3561/12571
# [train] chunk 36/126  sample 3571/12571
# [train] chunk 36/126  sample 3581/12571
# [train] chunk 36/126  sample 3591/12571
# ✅ saved: /content/graphs/train_chunk0035.pt (100 graphs)
# [train] chunk 37/126  sample 3601/12571
# [train] chunk 37/126  sample 3611/12571
# [train] chunk 37/126  sample 3621/12571
# [train] chunk 37/126  sample 3631/12571
# [train] chunk 37/126  sample 3641/12571
# [train] chunk 37/126  sample 3651/12571
# [train] chunk 37/126  sample 3661/12571
# [train] chunk 37/126  sample 3671/12571
# [train] chunk 37/126  sample 3681/12571
# [train] chunk 37/126  sample 3691/12571
# ✅ saved: /content/graphs/train_chunk0036.pt (100 graphs)
# [train] chunk 38/126  sample 3701/12571
# [train] chunk 38/126  sample 3711/12571
# [train] chunk 38/126  sample 3721/12571
# [train] chunk 38/126  sample 3731/12571
# [train] chunk 38/126  sample 3741/12571
# [train] chunk 38/126  sample 3751/12571
# [train] chunk 38/126  sample 3761/12571
# [train] chunk 38/126  sample 3771/12571
# [train] chunk 38/126  sample 3781/12571
# [train] chunk 38/126  sample 3791/12571
# ✅ saved: /content/graphs/train_chunk0037.pt (100 graphs)
# [train] chunk 39/126  sample 3801/12571
# [train] chunk 39/126  sample 3811/12571
# [train] chunk 39/126  sample 3821/12571
# [train] chunk 39/126  sample 3831/12571
# [train] chunk 39/126  sample 3841/12571
# [train] chunk 39/126  sample 3851/12571
# [train] chunk 39/126  sample 3861/12571
# [train] chunk 39/126  sample 3871/12571
# [train] chunk 39/126  sample 3881/12571
# [train] chunk 39/126  sample 3891/12571
# ✅ saved: /content/graphs/train_chunk0038.pt (100 graphs)
# [train] chunk 40/126  sample 3901/12571
# [train] chunk 40/126  sample 3911/12571
# [train] chunk 40/126  sample 3921/12571
# [train] chunk 40/126  sample 3931/12571
# [train] chunk 40/126  sample 3941/12571
# [train] chunk 40/126  sample 3951/12571
# [train] chunk 40/126  sample 3961/12571
# [train] chunk 40/126  sample 3971/12571
# [train] chunk 40/126  sample 3981/12571
# [train] chunk 40/126  sample 3991/12571
# ✅ saved: /content/graphs/train_chunk0039.pt (100 graphs)
# [train] chunk 41/126  sample 4001/12571
# [train] chunk 41/126  sample 4011/12571
# [train] chunk 41/126  sample 4021/12571
# [train] chunk 41/126  sample 4031/12571
# [train] chunk 41/126  sample 4041/12571
# [train] chunk 41/126  sample 4051/12571
# [train] chunk 41/126  sample 4061/12571
# [train] chunk 41/126  sample 4071/12571
# [train] chunk 41/126  sample 4081/12571
# [train] chunk 41/126  sample 4091/12571
# ✅ saved: /content/graphs/train_chunk0040.pt (100 graphs)
# [train] chunk 42/126  sample 4101/12571
# [train] chunk 42/126  sample 4111/12571
# [train] chunk 42/126  sample 4121/12571
# [train] chunk 42/126  sample 4131/12571
# [train] chunk 42/126  sample 4141/12571
# [train] chunk 42/126  sample 4151/12571
# [train] chunk 42/126  sample 4161/12571
# [train] chunk 42/126  sample 4171/12571
# [train] chunk 42/126  sample 4181/12571
# [train] chunk 42/126  sample 4191/12571
# ✅ saved: /content/graphs/train_chunk0041.pt (100 graphs)
# [train] chunk 43/126  sample 4201/12571
# [train] chunk 43/126  sample 4211/12571
# [train] chunk 43/126  sample 4221/12571
# [train] chunk 43/126  sample 4231/12571
# [train] chunk 43/126  sample 4241/12571
# [train] chunk 43/126  sample 4251/12571
# [train] chunk 43/126  sample 4261/12571
# [train] chunk 43/126  sample 4271/12571
# [train] chunk 43/126  sample 4281/12571
# [train] chunk 43/126  sample 4291/12571
# ✅ saved: /content/graphs/train_chunk0042.pt (100 graphs)
# [train] chunk 44/126  sample 4301/12571
# [train] chunk 44/126  sample 4311/12571
# [train] chunk 44/126  sample 4321/12571
# [train] chunk 44/126  sample 4331/12571
# [train] chunk 44/126  sample 4341/12571
# [train] chunk 44/126  sample 4351/12571
# [train] chunk 44/126  sample 4361/12571
# [train] chunk 44/126  sample 4371/12571
# [train] chunk 44/126  sample 4381/12571
# [train] chunk 44/126  sample 4391/12571
# ✅ saved: /content/graphs/train_chunk0043.pt (100 graphs)
# [train] chunk 45/126  sample 4401/12571
# [train] chunk 45/126  sample 4411/12571
# [train] chunk 45/126  sample 4421/12571
# [train] chunk 45/126  sample 4431/12571
# [train] chunk 45/126  sample 4441/12571
# [train] chunk 45/126  sample 4451/12571
# [train] chunk 45/126  sample 4461/12571
# [train] chunk 45/126  sample 4471/12571
# [train] chunk 45/126  sample 4481/12571
# [train] chunk 45/126  sample 4491/12571
# ✅ saved: /content/graphs/train_chunk0044.pt (100 graphs)
# [train] chunk 46/126  sample 4501/12571
# [train] chunk 46/126  sample 4511/12571
# [train] chunk 46/126  sample 4521/12571
# [train] chunk 46/126  sample 4531/12571
# [train] chunk 46/126  sample 4541/12571
# [train] chunk 46/126  sample 4551/12571
# [train] chunk 46/126  sample 4561/12571
# [train] chunk 46/126  sample 4571/12571
# [train] chunk 46/126  sample 4581/12571
# [train] chunk 46/126  sample 4591/12571
# ✅ saved: /content/graphs/train_chunk0045.pt (100 graphs)
# [train] chunk 47/126  sample 4601/12571
# [train] chunk 47/126  sample 4611/12571
# [train] chunk 47/126  sample 4621/12571
# [train] chunk 47/126  sample 4631/12571
# [train] chunk 47/126  sample 4641/12571
# [train] chunk 47/126  sample 4651/12571
# [train] chunk 47/126  sample 4661/12571
# [train] chunk 47/126  sample 4671/12571
# [train] chunk 47/126  sample 4681/12571
# [train] chunk 47/126  sample 4691/12571
# ✅ saved: /content/graphs/train_chunk0046.pt (100 graphs)
# [train] chunk 48/126  sample 4701/12571
# [train] chunk 48/126  sample 4711/12571
# [train] chunk 48/126  sample 4721/12571
# [train] chunk 48/126  sample 4731/12571
# [train] chunk 48/126  sample 4741/12571
# [train] chunk 48/126  sample 4751/12571
# [train] chunk 48/126  sample 4761/12571
# [train] chunk 48/126  sample 4771/12571
# [train] chunk 48/126  sample 4781/12571
# [train] chunk 48/126  sample 4791/12571
# ✅ saved: /content/graphs/train_chunk0047.pt (100 graphs)
# [train] chunk 49/126  sample 4801/12571
# [train] chunk 49/126  sample 4811/12571
# [train] chunk 49/126  sample 4821/12571
# [train] chunk 49/126  sample 4831/12571
# [train] chunk 49/126  sample 4841/12571
# [train] chunk 49/126  sample 4851/12571
# [train] chunk 49/126  sample 4861/12571
# [train] chunk 49/126  sample 4871/12571
# [train] chunk 49/126  sample 4881/12571
# [train] chunk 49/126  sample 4891/12571
# ✅ saved: /content/graphs/train_chunk0048.pt (100 graphs)
# [train] chunk 50/126  sample 4901/12571
# [train] chunk 50/126  sample 4911/12571
# [train] chunk 50/126  sample 4921/12571
# [train] chunk 50/126  sample 4931/12571
# [train] chunk 50/126  sample 4941/12571
# [train] chunk 50/126  sample 4951/12571
# [train] chunk 50/126  sample 4961/12571
# [train] chunk 50/126  sample 4971/12571
# [train] chunk 50/126  sample 4981/12571
# [train] chunk 50/126  sample 4991/12571
# ✅ saved: /content/graphs/train_chunk0049.pt (100 graphs)
# [train] chunk 51/126  sample 5001/12571
# [train] chunk 51/126  sample 5011/12571
# [train] chunk 51/126  sample 5021/12571
# [train] chunk 51/126  sample 5031/12571
# [train] chunk 51/126  sample 5041/12571
# [train] chunk 51/126  sample 5051/12571
# [train] chunk 51/126  sample 5061/12571
# [train] chunk 51/126  sample 5071/12571
# [train] chunk 51/126  sample 5081/12571
# [train] chunk 51/126  sample 5091/12571
# ✅ saved: /content/graphs/train_chunk0050.pt (100 graphs)
# [train] chunk 52/126  sample 5101/12571
# [train] chunk 52/126  sample 5111/12571
# [train] chunk 52/126  sample 5121/12571
# [train] chunk 52/126  sample 5131/12571
# [train] chunk 52/126  sample 5141/12571
# [train] chunk 52/126  sample 5151/12571
# [train] chunk 52/126  sample 5161/12571
# [train] chunk 52/126  sample 5171/12571
# [train] chunk 52/126  sample 5181/12571
# [train] chunk 52/126  sample 5191/12571
# ✅ saved: /content/graphs/train_chunk0051.pt (100 graphs)
# [train] chunk 53/126  sample 5201/12571
# [train] chunk 53/126  sample 5211/12571
# [train] chunk 53/126  sample 5221/12571
# [train] chunk 53/126  sample 5231/12571
# [train] chunk 53/126  sample 5241/12571
# [train] chunk 53/126  sample 5251/12571
# [train] chunk 53/126  sample 5261/12571
# [train] chunk 53/126  sample 5271/12571
# [train] chunk 53/126  sample 5281/12571
# [train] chunk 53/126  sample 5291/12571
# ✅ saved: /content/graphs/train_chunk0052.pt (100 graphs)
# [train] chunk 54/126  sample 5301/12571
# [train] chunk 54/126  sample 5311/12571
# [train] chunk 54/126  sample 5321/12571
# [train] chunk 54/126  sample 5331/12571
# [train] chunk 54/126  sample 5341/12571
# [train] chunk 54/126  sample 5351/12571
# [train] chunk 54/126  sample 5361/12571
# [train] chunk 54/126  sample 5371/12571
# [train] chunk 54/126  sample 5381/12571
# [train] chunk 54/126  sample 5391/12571
# ✅ saved: /content/graphs/train_chunk0053.pt (100 graphs)
# [train] chunk 55/126  sample 5401/12571
# [train] chunk 55/126  sample 5411/12571
# [train] chunk 55/126  sample 5421/12571
# [train] chunk 55/126  sample 5431/12571
# [train] chunk 55/126  sample 5441/12571
# [train] chunk 55/126  sample 5451/12571
# [train] chunk 55/126  sample 5461/12571
# [train] chunk 55/126  sample 5471/12571
# [train] chunk 55/126  sample 5481/12571
# [train] chunk 55/126  sample 5491/12571
# ✅ saved: /content/graphs/train_chunk0054.pt (100 graphs)
# [train] chunk 56/126  sample 5501/12571
# [train] chunk 56/126  sample 5511/12571
# [train] chunk 56/126  sample 5521/12571
# [train] chunk 56/126  sample 5531/12571
# [train] chunk 56/126  sample 5541/12571
# [train] chunk 56/126  sample 5551/12571
# [train] chunk 56/126  sample 5561/12571
# [train] chunk 56/126  sample 5571/12571
# [train] chunk 56/126  sample 5581/12571
# [train] chunk 56/126  sample 5591/12571
# ✅ saved: /content/graphs/train_chunk0055.pt (100 graphs)
# [train] chunk 57/126  sample 5601/12571
# [train] chunk 57/126  sample 5611/12571
# [train] chunk 57/126  sample 5621/12571
# [train] chunk 57/126  sample 5631/12571
# [train] chunk 57/126  sample 5641/12571
# [train] chunk 57/126  sample 5651/12571
# [train] chunk 57/126  sample 5661/12571
# [train] chunk 57/126  sample 5671/12571
# [train] chunk 57/126  sample 5681/12571
# [train] chunk 57/126  sample 5691/12571
# ✅ saved: /content/graphs/train_chunk0056.pt (100 graphs)
# [train] chunk 58/126  sample 5701/12571
# [train] chunk 58/126  sample 5711/12571
# [train] chunk 58/126  sample 5721/12571
# [train] chunk 58/126  sample 5731/12571
# [train] chunk 58/126  sample 5741/12571
# [train] chunk 58/126  sample 5751/12571
# [train] chunk 58/126  sample 5761/12571
# [train] chunk 58/126  sample 5771/12571
# [train] chunk 58/126  sample 5781/12571
# [train] chunk 58/126  sample 5791/12571
# ✅ saved: /content/graphs/train_chunk0057.pt (100 graphs)
# [train] chunk 59/126  sample 5801/12571
# [train] chunk 59/126  sample 5811/12571
# [train] chunk 59/126  sample 5821/12571
# [train] chunk 59/126  sample 5831/12571
# [train] chunk 59/126  sample 5841/12571
# [train] chunk 59/126  sample 5851/12571
# [train] chunk 59/126  sample 5861/12571
# [train] chunk 59/126  sample 5871/12571
# [train] chunk 59/126  sample 5881/12571
# [train] chunk 59/126  sample 5891/12571
# ✅ saved: /content/graphs/train_chunk0058.pt (100 graphs)
# [train] chunk 60/126  sample 5901/12571
# [train] chunk 60/126  sample 5911/12571
# [train] chunk 60/126  sample 5921/12571
# [train] chunk 60/126  sample 5931/12571
# [train] chunk 60/126  sample 5941/12571
# [train] chunk 60/126  sample 5951/12571
# [train] chunk 60/126  sample 5961/12571
# [train] chunk 60/126  sample 5971/12571
# [train] chunk 60/126  sample 5981/12571
# [train] chunk 60/126  sample 5991/12571
# ✅ saved: /content/graphs/train_chunk0059.pt (100 graphs)
# [train] chunk 61/126  sample 6001/12571
# [train] chunk 61/126  sample 6011/12571
# [train] chunk 61/126  sample 6021/12571
# [train] chunk 61/126  sample 6031/12571
# [train] chunk 61/126  sample 6041/12571
# [train] chunk 61/126  sample 6051/12571
# [train] chunk 61/126  sample 6061/12571
# [train] chunk 61/126  sample 6071/12571
# [train] chunk 61/126  sample 6081/12571
# [train] chunk 61/126  sample 6091/12571
# ✅ saved: /content/graphs/train_chunk0060.pt (100 graphs)
# [train] chunk 62/126  sample 6101/12571
# [train] chunk 62/126  sample 6111/12571
# [train] chunk 62/126  sample 6121/12571
# [train] chunk 62/126  sample 6131/12571
# [train] chunk 62/126  sample 6141/12571
# [train] chunk 62/126  sample 6151/12571
# [train] chunk 62/126  sample 6161/12571
# [train] chunk 62/126  sample 6171/12571
# [train] chunk 62/126  sample 6181/12571
# [train] chunk 62/126  sample 6191/12571
# ✅ saved: /content/graphs/train_chunk0061.pt (100 graphs)
# [train] chunk 63/126  sample 6201/12571
# [train] chunk 63/126  sample 6211/12571
# [train] chunk 63/126  sample 6221/12571
# [train] chunk 63/126  sample 6231/12571
# [train] chunk 63/126  sample 6241/12571
# [train] chunk 63/126  sample 6251/12571
# [train] chunk 63/126  sample 6261/12571
# [train] chunk 63/126  sample 6271/12571
# [train] chunk 63/126  sample 6281/12571
# [train] chunk 63/126  sample 6291/12571
# ✅ saved: /content/graphs/train_chunk0062.pt (100 graphs)
# [train] chunk 64/126  sample 6301/12571
# [train] chunk 64/126  sample 6311/12571
# [train] chunk 64/126  sample 6321/12571
# [train] chunk 64/126  sample 6331/12571
# [train] chunk 64/126  sample 6341/12571
# [train] chunk 64/126  sample 6351/12571
# [train] chunk 64/126  sample 6361/12571
# [train] chunk 64/126  sample 6371/12571
# [train] chunk 64/126  sample 6381/12571
# [train] chunk 64/126  sample 6391/12571
# ✅ saved: /content/graphs/train_chunk0063.pt (100 graphs)
# [train] chunk 65/126  sample 6401/12571
# [train] chunk 65/126  sample 6411/12571
# [train] chunk 65/126  sample 6421/12571
# [train] chunk 65/126  sample 6431/12571
# [train] chunk 65/126  sample 6441/12571
# [train] chunk 65/126  sample 6451/12571
# [train] chunk 65/126  sample 6461/12571
# [train] chunk 65/126  sample 6471/12571
# [train] chunk 65/126  sample 6481/12571
# [train] chunk 65/126  sample 6491/12571
# ✅ saved: /content/graphs/train_chunk0064.pt (100 graphs)
# [train] chunk 66/126  sample 6501/12571
# [train] chunk 66/126  sample 6511/12571
# [train] chunk 66/126  sample 6521/12571
# [train] chunk 66/126  sample 6531/12571
# [train] chunk 66/126  sample 6541/12571
# [train] chunk 66/126  sample 6551/12571
# [train] chunk 66/126  sample 6561/12571
# [train] chunk 66/126  sample 6571/12571
# [train] chunk 66/126  sample 6581/12571
# [train] chunk 66/126  sample 6591/12571
# ✅ saved: /content/graphs/train_chunk0065.pt (100 graphs)
# [train] chunk 67/126  sample 6601/12571
# [train] chunk 67/126  sample 6611/12571
# [train] chunk 67/126  sample 6621/12571
# [train] chunk 67/126  sample 6631/12571
# [train] chunk 67/126  sample 6641/12571
# [train] chunk 67/126  sample 6651/12571
# [train] chunk 67/126  sample 6661/12571
# [train] chunk 67/126  sample 6671/12571
# [train] chunk 67/126  sample 6681/12571
# [train] chunk 67/126  sample 6691/12571
# ✅ saved: /content/graphs/train_chunk0066.pt (100 graphs)
# [train] chunk 68/126  sample 6701/12571
# [train] chunk 68/126  sample 6711/12571
# [train] chunk 68/126  sample 6721/12571
# [train] chunk 68/126  sample 6731/12571
# [train] chunk 68/126  sample 6741/12571
# [train] chunk 68/126  sample 6751/12571
# [train] chunk 68/126  sample 6761/12571
# [train] chunk 68/126  sample 6771/12571
# [train] chunk 68/126  sample 6781/12571
# [train] chunk 68/126  sample 6791/12571
# ✅ saved: /content/graphs/train_chunk0067.pt (100 graphs)
# [train] chunk 69/126  sample 6801/12571
# [train] chunk 69/126  sample 6811/12571
# [train] chunk 69/126  sample 6821/12571
# [train] chunk 69/126  sample 6831/12571
# [train] chunk 69/126  sample 6841/12571
# [train] chunk 69/126  sample 6851/12571
# [train] chunk 69/126  sample 6861/12571
# [train] chunk 69/126  sample 6871/12571
# [train] chunk 69/126  sample 6881/12571
# [train] chunk 69/126  sample 6891/12571
# ✅ saved: /content/graphs/train_chunk0068.pt (100 graphs)
# [train] chunk 70/126  sample 6901/12571
# [train] chunk 70/126  sample 6911/12571
# [train] chunk 70/126  sample 6921/12571
# [train] chunk 70/126  sample 6931/12571
# [train] chunk 70/126  sample 6941/12571
# [train] chunk 70/126  sample 6951/12571
# [train] chunk 70/126  sample 6961/12571
# [train] chunk 70/126  sample 6971/12571
# [train] chunk 70/126  sample 6981/12571
# [train] chunk 70/126  sample 6991/12571
# ✅ saved: /content/graphs/train_chunk0069.pt (100 graphs)
# [train] chunk 71/126  sample 7001/12571
# [train] chunk 71/126  sample 7011/12571
# [train] chunk 71/126  sample 7021/12571
# [train] chunk 71/126  sample 7031/12571
# [train] chunk 71/126  sample 7041/12571
# [train] chunk 71/126  sample 7051/12571
# [train] chunk 71/126  sample 7061/12571
# [train] chunk 71/126  sample 7071/12571
# [train] chunk 71/126  sample 7081/12571
# [train] chunk 71/126  sample 7091/12571
# ✅ saved: /content/graphs/train_chunk0070.pt (100 graphs)
# [train] chunk 72/126  sample 7101/12571
# [train] chunk 72/126  sample 7111/12571
# [train] chunk 72/126  sample 7121/12571
# [train] chunk 72/126  sample 7131/12571
# [train] chunk 72/126  sample 7141/12571
# [train] chunk 72/126  sample 7151/12571
# [train] chunk 72/126  sample 7161/12571
# [train] chunk 72/126  sample 7171/12571
# [train] chunk 72/126  sample 7181/12571
# [train] chunk 72/126  sample 7191/12571
# ✅ saved: /content/graphs/train_chunk0071.pt (100 graphs)
# [train] chunk 73/126  sample 7201/12571
# [train] chunk 73/126  sample 7211/12571
# [train] chunk 73/126  sample 7221/12571
# [train] chunk 73/126  sample 7231/12571
# [train] chunk 73/126  sample 7241/12571
# [train] chunk 73/126  sample 7251/12571
# [train] chunk 73/126  sample 7261/12571
# [train] chunk 73/126  sample 7271/12571
# [train] chunk 73/126  sample 7281/12571
# [train] chunk 73/126  sample 7291/12571
# ✅ saved: /content/graphs/train_chunk0072.pt (100 graphs)
# [train] chunk 74/126  sample 7301/12571
# [train] chunk 74/126  sample 7311/12571
# [train] chunk 74/126  sample 7321/12571
# [train] chunk 74/126  sample 7331/12571
# [train] chunk 74/126  sample 7341/12571
# [train] chunk 74/126  sample 7351/12571
# [train] chunk 74/126  sample 7361/12571
# [train] chunk 74/126  sample 7371/12571
# [train] chunk 74/126  sample 7381/12571
# [train] chunk 74/126  sample 7391/12571
# ✅ saved: /content/graphs/train_chunk0073.pt (100 graphs)
# [train] chunk 75/126  sample 7401/12571
# [train] chunk 75/126  sample 7411/12571
# [train] chunk 75/126  sample 7421/12571
# [train] chunk 75/126  sample 7431/12571
# [train] chunk 75/126  sample 7441/12571
# [train] chunk 75/126  sample 7451/12571
# [train] chunk 75/126  sample 7461/12571
# [train] chunk 75/126  sample 7471/12571
# [train] chunk 75/126  sample 7481/12571
# [train] chunk 75/126  sample 7491/12571
# ✅ saved: /content/graphs/train_chunk0074.pt (100 graphs)
# [train] chunk 76/126  sample 7501/12571
# [train] chunk 76/126  sample 7511/12571
# [train] chunk 76/126  sample 7521/12571
# [train] chunk 76/126  sample 7531/12571
# [train] chunk 76/126  sample 7541/12571
# [train] chunk 76/126  sample 7551/12571
# [train] chunk 76/126  sample 7561/12571
# [train] chunk 76/126  sample 7571/12571
# [train] chunk 76/126  sample 7581/12571
# [train] chunk 76/126  sample 7591/12571
# ✅ saved: /content/graphs/train_chunk0075.pt (100 graphs)
# [train] chunk 77/126  sample 7601/12571
# [train] chunk 77/126  sample 7611/12571
# [train] chunk 77/126  sample 7621/12571
# [train] chunk 77/126  sample 7631/12571
# [train] chunk 77/126  sample 7641/12571
# [train] chunk 77/126  sample 7651/12571
# [train] chunk 77/126  sample 7661/12571
# [train] chunk 77/126  sample 7671/12571
# [train] chunk 77/126  sample 7681/12571
# [train] chunk 77/126  sample 7691/12571
# ✅ saved: /content/graphs/train_chunk0076.pt (100 graphs)
# [train] chunk 78/126  sample 7701/12571
# [train] chunk 78/126  sample 7711/12571
# [train] chunk 78/126  sample 7721/12571
# [train] chunk 78/126  sample 7731/12571
# [train] chunk 78/126  sample 7741/12571
# [train] chunk 78/126  sample 7751/12571
# [train] chunk 78/126  sample 7761/12571
# [train] chunk 78/126  sample 7771/12571
# [train] chunk 78/126  sample 7781/12571
# [train] chunk 78/126  sample 7791/12571
# ✅ saved: /content/graphs/train_chunk0077.pt (100 graphs)
# [train] chunk 79/126  sample 7801/12571
# [train] chunk 79/126  sample 7811/12571
# [train] chunk 79/126  sample 7821/12571
# [train] chunk 79/126  sample 7831/12571
# [train] chunk 79/126  sample 7841/12571
# [train] chunk 79/126  sample 7851/12571
# [train] chunk 79/126  sample 7861/12571
# [train] chunk 79/126  sample 7871/12571
# [train] chunk 79/126  sample 7881/12571
# [train] chunk 79/126  sample 7891/12571
# ✅ saved: /content/graphs/train_chunk0078.pt (100 graphs)
# [train] chunk 80/126  sample 7901/12571
# [train] chunk 80/126  sample 7911/12571
# [train] chunk 80/126  sample 7921/12571
# [train] chunk 80/126  sample 7931/12571
# [train] chunk 80/126  sample 7941/12571
# [train] chunk 80/126  sample 7951/12571
# [train] chunk 80/126  sample 7961/12571
# [train] chunk 80/126  sample 7971/12571
# [train] chunk 80/126  sample 7981/12571
# [train] chunk 80/126  sample 7991/12571
# ✅ saved: /content/graphs/train_chunk0079.pt (100 graphs)
# [train] chunk 81/126  sample 8001/12571
# [train] chunk 81/126  sample 8011/12571
# [train] chunk 81/126  sample 8021/12571
# [train] chunk 81/126  sample 8031/12571
# [train] chunk 81/126  sample 8041/12571
# [train] chunk 81/126  sample 8051/12571
# [train] chunk 81/126  sample 8061/12571
# [train] chunk 81/126  sample 8071/12571
# [train] chunk 81/126  sample 8081/12571
# [train] chunk 81/126  sample 8091/12571
# ✅ saved: /content/graphs/train_chunk0080.pt (100 graphs)
# [train] chunk 82/126  sample 8101/12571
# [train] chunk 82/126  sample 8111/12571
# [train] chunk 82/126  sample 8121/12571
# [train] chunk 82/126  sample 8131/12571
# [train] chunk 82/126  sample 8141/12571
# [train] chunk 82/126  sample 8151/12571
# [train] chunk 82/126  sample 8161/12571
# [train] chunk 82/126  sample 8171/12571
# [train] chunk 82/126  sample 8181/12571
# [train] chunk 82/126  sample 8191/12571
# ✅ saved: /content/graphs/train_chunk0081.pt (100 graphs)
# [train] chunk 83/126  sample 8201/12571
# [train] chunk 83/126  sample 8211/12571
# [train] chunk 83/126  sample 8221/12571
# [train] chunk 83/126  sample 8231/12571
# [train] chunk 83/126  sample 8241/12571
# [train] chunk 83/126  sample 8251/12571
# [train] chunk 83/126  sample 8261/12571
# [train] chunk 83/126  sample 8271/12571
# [train] chunk 83/126  sample 8281/12571
# [train] chunk 83/126  sample 8291/12571
# ✅ saved: /content/graphs/train_chunk0082.pt (100 graphs)
# [train] chunk 84/126  sample 8301/12571
# [train] chunk 84/126  sample 8311/12571
# [train] chunk 84/126  sample 8321/12571
# [train] chunk 84/126  sample 8331/12571
# [train] chunk 84/126  sample 8341/12571
# [train] chunk 84/126  sample 8351/12571
# [train] chunk 84/126  sample 8361/12571
# [train] chunk 84/126  sample 8371/12571
# [train] chunk 84/126  sample 8381/12571
# [train] chunk 84/126  sample 8391/12571
# ✅ saved: /content/graphs/train_chunk0083.pt (100 graphs)
# [train] chunk 85/126  sample 8401/12571
# [train] chunk 85/126  sample 8411/12571
# [train] chunk 85/126  sample 8421/12571
# [train] chunk 85/126  sample 8431/12571
# [train] chunk 85/126  sample 8441/12571
# [train] chunk 85/126  sample 8451/12571
# [train] chunk 85/126  sample 8461/12571
# [train] chunk 85/126  sample 8471/12571
# [train] chunk 85/126  sample 8481/12571
# [train] chunk 85/126  sample 8491/12571
# ✅ saved: /content/graphs/train_chunk0084.pt (100 graphs)
# [train] chunk 86/126  sample 8501/12571
# [train] chunk 86/126  sample 8511/12571
# [train] chunk 86/126  sample 8521/12571
# [train] chunk 86/126  sample 8531/12571
# [train] chunk 86/126  sample 8541/12571
# [train] chunk 86/126  sample 8551/12571
# [train] chunk 86/126  sample 8561/12571
# [train] chunk 86/126  sample 8571/12571
# [train] chunk 86/126  sample 8581/12571
# [train] chunk 86/126  sample 8591/12571
# ✅ saved: /content/graphs/train_chunk0085.pt (100 graphs)
# [train] chunk 87/126  sample 8601/12571
# [train] chunk 87/126  sample 8611/12571
# [train] chunk 87/126  sample 8621/12571
# [train] chunk 87/126  sample 8631/12571
# [train] chunk 87/126  sample 8641/12571
# [train] chunk 87/126  sample 8651/12571
# [train] chunk 87/126  sample 8661/12571
# [train] chunk 87/126  sample 8671/12571
# [train] chunk 87/126  sample 8681/12571
# [train] chunk 87/126  sample 8691/12571
# ✅ saved: /content/graphs/train_chunk0086.pt (100 graphs)
# [train] chunk 88/126  sample 8701/12571
# [train] chunk 88/126  sample 8711/12571
# [train] chunk 88/126  sample 8721/12571
# [train] chunk 88/126  sample 8731/12571
# [train] chunk 88/126  sample 8741/12571
# [train] chunk 88/126  sample 8751/12571
# [train] chunk 88/126  sample 8761/12571
# [train] chunk 88/126  sample 8771/12571
# [train] chunk 88/126  sample 8781/12571
# [train] chunk 88/126  sample 8791/12571
# ✅ saved: /content/graphs/train_chunk0087.pt (100 graphs)
# [train] chunk 89/126  sample 8801/12571
# [train] chunk 89/126  sample 8811/12571
# [train] chunk 89/126  sample 8821/12571
# [train] chunk 89/126  sample 8831/12571
# [train] chunk 89/126  sample 8841/12571
# [train] chunk 89/126  sample 8851/12571
# [train] chunk 89/126  sample 8861/12571
# [train] chunk 89/126  sample 8871/12571
# [train] chunk 89/126  sample 8881/12571
# [train] chunk 89/126  sample 8891/12571
# ✅ saved: /content/graphs/train_chunk0088.pt (100 graphs)
# [train] chunk 90/126  sample 8901/12571
# [train] chunk 90/126  sample 8911/12571
# [train] chunk 90/126  sample 8921/12571
# [train] chunk 90/126  sample 8931/12571
# [train] chunk 90/126  sample 8941/12571
# [train] chunk 90/126  sample 8951/12571
# [train] chunk 90/126  sample 8961/12571
# [train] chunk 90/126  sample 8971/12571
# [train] chunk 90/126  sample 8981/12571
# [train] chunk 90/126  sample 8991/12571
# ✅ saved: /content/graphs/train_chunk0089.pt (100 graphs)
# [train] chunk 91/126  sample 9001/12571
# [train] chunk 91/126  sample 9011/12571
# [train] chunk 91/126  sample 9021/12571
# [train] chunk 91/126  sample 9031/12571
# [train] chunk 91/126  sample 9041/12571
# [train] chunk 91/126  sample 9051/12571
# [train] chunk 91/126  sample 9061/12571
# [train] chunk 91/126  sample 9071/12571
# [train] chunk 91/126  sample 9081/12571
# [train] chunk 91/126  sample 9091/12571
# ✅ saved: /content/graphs/train_chunk0090.pt (100 graphs)
# [train] chunk 92/126  sample 9101/12571
# [train] chunk 92/126  sample 9111/12571
# [train] chunk 92/126  sample 9121/12571
# [train] chunk 92/126  sample 9131/12571
# [train] chunk 92/126  sample 9141/12571
# [train] chunk 92/126  sample 9151/12571
# [train] chunk 92/126  sample 9161/12571
# [train] chunk 92/126  sample 9171/12571
# [train] chunk 92/126  sample 9181/12571
# [train] chunk 92/126  sample 9191/12571
# ✅ saved: /content/graphs/train_chunk0091.pt (100 graphs)
# [train] chunk 93/126  sample 9201/12571
# [train] chunk 93/126  sample 9211/12571
# [train] chunk 93/126  sample 9221/12571
# [train] chunk 93/126  sample 9231/12571
# [train] chunk 93/126  sample 9241/12571
# [train] chunk 93/126  sample 9251/12571
# [train] chunk 93/126  sample 9261/12571
# [train] chunk 93/126  sample 9271/12571
# [train] chunk 93/126  sample 9281/12571
# [train] chunk 93/126  sample 9291/12571
# ✅ saved: /content/graphs/train_chunk0092.pt (100 graphs)
# [train] chunk 94/126  sample 9301/12571
# [train] chunk 94/126  sample 9311/12571
# [train] chunk 94/126  sample 9321/12571
# [train] chunk 94/126  sample 9331/12571
# [train] chunk 94/126  sample 9341/12571
# [train] chunk 94/126  sample 9351/12571
# [train] chunk 94/126  sample 9361/12571
# [train] chunk 94/126  sample 9371/12571
# [train] chunk 94/126  sample 9381/12571
# [train] chunk 94/126  sample 9391/12571
# ✅ saved: /content/graphs/train_chunk0093.pt (100 graphs)
# [train] chunk 95/126  sample 9401/12571
# [train] chunk 95/126  sample 9411/12571
# [train] chunk 95/126  sample 9421/12571
# [train] chunk 95/126  sample 9431/12571
# [train] chunk 95/126  sample 9441/12571
# [train] chunk 95/126  sample 9451/12571
# [train] chunk 95/126  sample 9461/12571
# [train] chunk 95/126  sample 9471/12571
# [train] chunk 95/126  sample 9481/12571
# [train] chunk 95/126  sample 9491/12571
# ✅ saved: /content/graphs/train_chunk0094.pt (100 graphs)
# [train] chunk 96/126  sample 9501/12571
# [train] chunk 96/126  sample 9511/12571
# [train] chunk 96/126  sample 9521/12571
# [train] chunk 96/126  sample 9531/12571
# [train] chunk 96/126  sample 9541/12571
# [train] chunk 96/126  sample 9551/12571
# [train] chunk 96/126  sample 9561/12571
# [train] chunk 96/126  sample 9571/12571
# [train] chunk 96/126  sample 9581/12571
# [train] chunk 96/126  sample 9591/12571
# ✅ saved: /content/graphs/train_chunk0095.pt (100 graphs)
# [train] chunk 97/126  sample 9601/12571
# [train] chunk 97/126  sample 9611/12571
# [train] chunk 97/126  sample 9621/12571
# [train] chunk 97/126  sample 9631/12571
# [train] chunk 97/126  sample 9641/12571
# [train] chunk 97/126  sample 9651/12571
# [train] chunk 97/126  sample 9661/12571
# [train] chunk 97/126  sample 9671/12571
# [train] chunk 97/126  sample 9681/12571
# [train] chunk 97/126  sample 9691/12571
# ✅ saved: /content/graphs/train_chunk0096.pt (100 graphs)
# [train] chunk 98/126  sample 9701/12571
# [train] chunk 98/126  sample 9711/12571
# [train] chunk 98/126  sample 9721/12571
# [train] chunk 98/126  sample 9731/12571
# [train] chunk 98/126  sample 9741/12571
# [train] chunk 98/126  sample 9751/12571
# [train] chunk 98/126  sample 9761/12571
# [train] chunk 98/126  sample 9771/12571
# [train] chunk 98/126  sample 9781/12571
# [train] chunk 98/126  sample 9791/12571
# ✅ saved: /content/graphs/train_chunk0097.pt (100 graphs)
# [train] chunk 99/126  sample 9801/12571
# [train] chunk 99/126  sample 9811/12571
# [train] chunk 99/126  sample 9821/12571
# [train] chunk 99/126  sample 9831/12571
# [train] chunk 99/126  sample 9841/12571
# [train] chunk 99/126  sample 9851/12571
# [train] chunk 99/126  sample 9861/12571
# [train] chunk 99/126  sample 9871/12571
# [train] chunk 99/126  sample 9881/12571
# [train] chunk 99/126  sample 9891/12571
# ✅ saved: /content/graphs/train_chunk0098.pt (100 graphs)
# [train] chunk 100/126  sample 9901/12571
# [train] chunk 100/126  sample 9911/12571
# [train] chunk 100/126  sample 9921/12571
# [train] chunk 100/126  sample 9931/12571
# [train] chunk 100/126  sample 9941/12571
# [train] chunk 100/126  sample 9951/12571
# [train] chunk 100/126  sample 9961/12571
# [train] chunk 100/126  sample 9971/12571
# [train] chunk 100/126  sample 9981/12571
# [train] chunk 100/126  sample 9991/12571
# ✅ saved: /content/graphs/train_chunk0099.pt (100 graphs)
# [train] chunk 101/126  sample 10001/12571
# [train] chunk 101/126  sample 10011/12571
# [train] chunk 101/126  sample 10021/12571
# [train] chunk 101/126  sample 10031/12571
# [train] chunk 101/126  sample 10041/12571
# [train] chunk 101/126  sample 10051/12571
# [train] chunk 101/126  sample 10061/12571
# [train] chunk 101/126  sample 10071/12571
# [train] chunk 101/126  sample 10081/12571
# [train] chunk 101/126  sample 10091/12571
# ✅ saved: /content/graphs/train_chunk0100.pt (100 graphs)
# [train] chunk 102/126  sample 10101/12571
# [train] chunk 102/126  sample 10111/12571
# [train] chunk 102/126  sample 10121/12571
# [train] chunk 102/126  sample 10131/12571
# [train] chunk 102/126  sample 10141/12571
# [train] chunk 102/126  sample 10151/12571
# [train] chunk 102/126  sample 10161/12571
# [train] chunk 102/126  sample 10171/12571
# [train] chunk 102/126  sample 10181/12571
# [train] chunk 102/126  sample 10191/12571
# ✅ saved: /content/graphs/train_chunk0101.pt (100 graphs)
# [train] chunk 103/126  sample 10201/12571
# [train] chunk 103/126  sample 10211/12571
# [train] chunk 103/126  sample 10221/12571
# [train] chunk 103/126  sample 10231/12571
# [train] chunk 103/126  sample 10241/12571
# [train] chunk 103/126  sample 10251/12571
# [train] chunk 103/126  sample 10261/12571
# [train] chunk 103/126  sample 10271/12571
# [train] chunk 103/126  sample 10281/12571
# [train] chunk 103/126  sample 10291/12571
# ✅ saved: /content/graphs/train_chunk0102.pt (100 graphs)
# [train] chunk 104/126  sample 10301/12571
# [train] chunk 104/126  sample 10311/12571
# [train] chunk 104/126  sample 10321/12571
# [train] chunk 104/126  sample 10331/12571
# [train] chunk 104/126  sample 10341/12571
# ...
# [val] chunk 51/89  sample 5001/8831
# [val] chunk 51/89  sample 5011/8831
# [val] chunk 51/89  sample 5021/8831
# [val] chunk 51/89  sample 5031/8831
# [val] chunk 51/89  sample 5041/8831
# [val] chunk 51/89  sample 5051/8831
# [val] chunk 51/89  sample 5061/8831
# [val] chunk 51/89  sample 5071/8831
# [val] chunk 51/89  sample 5081/8831
# [val] chunk 51/89  sample 5091/8831
# ✅ saved: /content/graphs/val_chunk0050.pt (100 graphs)
# [val] chunk 52/89  sample 5101/8831
# [val] chunk 52/89  sample 5111/8831
# [val] chunk 52/89  sample 5121/8831
# [val] chunk 52/89  sample 5131/8831
# [val] chunk 52/89  sample 5141/8831
# [val] chunk 52/89  sample 5151/8831
# [val] chunk 52/89  sample 5161/8831
# [val] chunk 52/89  sample 5171/8831
# [val] chunk 52/89  sample 5181/8831
# [val] chunk 52/89  sample 5191/8831
# ✅ saved: /content/graphs/val_chunk0051.pt (100 graphs)
# [val] chunk 53/89  sample 5201/8831
# [val] chunk 53/89  sample 5211/8831
# [val] chunk 53/89  sample 5221/8831
# [val] chunk 53/89  sample 5231/8831
# [val] chunk 53/89  sample 5241/8831
# [val] chunk 53/89  sample 5251/8831
# [val] chunk 53/89  sample 5261/8831
# [val] chunk 53/89  sample 5271/8831
# [val] chunk 53/89  sample 5281/8831
# [val] chunk 53/89  sample 5291/8831
# ✅ saved: /content/graphs/val_chunk0052.pt (100 graphs)
# [val] chunk 54/89  sample 5301/8831
# [val] chunk 54/89  sample 5311/8831
# [val] chunk 54/89  sample 5321/8831
# [val] chunk 54/89  sample 5331/8831
# [val] chunk 54/89  sample 5341/8831
# [val] chunk 54/89  sample 5351/8831
# [val] chunk 54/89  sample 5361/8831
# [val] chunk 54/89  sample 5371/8831
# [val] chunk 54/89  sample 5381/8831
# [val] chunk 54/89  sample 5391/8831
# ✅ saved: /content/graphs/val_chunk0053.pt (100 graphs)
# [val] chunk 55/89  sample 5401/8831
# [val] chunk 55/89  sample 5411/8831
# [val] chunk 55/89  sample 5421/8831
# [val] chunk 55/89  sample 5431/8831
# [val] chunk 55/89  sample 5441/8831
# [val] chunk 55/89  sample 5451/8831
# [val] chunk 55/89  sample 5461/8831
# [val] chunk 55/89  sample 5471/8831
# [val] chunk 55/89  sample 5481/8831
# [val] chunk 55/89  sample 5491/8831
# ✅ saved: /content/graphs/val_chunk0054.pt (100 graphs)
# [val] chunk 56/89  sample 5501/8831
# [val] chunk 56/89  sample 5511/8831
# [val] chunk 56/89  sample 5521/8831
# [val] chunk 56/89  sample 5531/8831
# [val] chunk 56/89  sample 5541/8831
# [val] chunk 56/89  sample 5551/8831
# [val] chunk 56/89  sample 5561/8831
# [val] chunk 56/89  sample 5571/8831
# [val] chunk 56/89  sample 5581/8831
# [val] chunk 56/89  sample 5591/8831
# ✅ saved: /content/graphs/val_chunk0055.pt (100 graphs)
# [val] chunk 57/89  sample 5601/8831
# [val] chunk 57/89  sample 5611/8831
# [val] chunk 57/89  sample 5621/8831
# [val] chunk 57/89  sample 5631/8831
# [val] chunk 57/89  sample 5641/8831
# [val] chunk 57/89  sample 5651/8831
# [val] chunk 57/89  sample 5661/8831
# [val] chunk 57/89  sample 5671/8831
# [val] chunk 57/89  sample 5681/8831
# [val] chunk 57/89  sample 5691/8831
# ✅ saved: /content/graphs/val_chunk0056.pt (100 graphs)
# [val] chunk 58/89  sample 5701/8831
# [val] chunk 58/89  sample 5711/8831
# [val] chunk 58/89  sample 5721/8831
# [val] chunk 58/89  sample 5731/8831
# [val] chunk 58/89  sample 5741/8831
# [val] chunk 58/89  sample 5751/8831
# [val] chunk 58/89  sample 5761/8831
# [val] chunk 58/89  sample 5771/8831
# [val] chunk 58/89  sample 5781/8831
# [val] chunk 58/89  sample 5791/8831
# ✅ saved: /content/graphs/val_chunk0057.pt (100 graphs)
# [val] chunk 59/89  sample 5801/8831
# [val] chunk 59/89  sample 5811/8831
# [val] chunk 59/89  sample 5821/8831
# [val] chunk 59/89  sample 5831/8831
# [val] chunk 59/89  sample 5841/8831
# [val] chunk 59/89  sample 5851/8831
# [val] chunk 59/89  sample 5861/8831
# [val] chunk 59/89  sample 5871/8831
# [val] chunk 59/89  sample 5881/8831
# [val] chunk 59/89  sample 5891/8831
# ✅ saved: /content/graphs/val_chunk0058.pt (100 graphs)
# [val] chunk 60/89  sample 5901/8831
# [val] chunk 60/89  sample 5911/8831
# [val] chunk 60/89  sample 5921/8831
# [val] chunk 60/89  sample 5931/8831
# [val] chunk 60/89  sample 5941/8831
# [val] chunk 60/89  sample 5951/8831
# [val] chunk 60/89  sample 5961/8831
# [val] chunk 60/89  sample 5971/8831
# [val] chunk 60/89  sample 5981/8831
# [val] chunk 60/89  sample 5991/8831
# ✅ saved: /content/graphs/val_chunk0059.pt (100 graphs)
# [val] chunk 61/89  sample 6001/8831
# [val] chunk 61/89  sample 6011/8831
# [val] chunk 61/89  sample 6021/8831
# [val] chunk 61/89  sample 6031/8831
# [val] chunk 61/89  sample 6041/8831
# [val] chunk 61/89  sample 6051/8831
# [val] chunk 61/89  sample 6061/8831
# [val] chunk 61/89  sample 6071/8831
# [val] chunk 61/89  sample 6081/8831
# [val] chunk 61/89  sample 6091/8831
# ✅ saved: /content/graphs/val_chunk0060.pt (100 graphs)
# [val] chunk 62/89  sample 6101/8831
# [val] chunk 62/89  sample 6111/8831
# [val] chunk 62/89  sample 6121/8831
# [val] chunk 62/89  sample 6131/8831
# [val] chunk 62/89  sample 6141/8831
# [val] chunk 62/89  sample 6151/8831
# [val] chunk 62/89  sample 6161/8831
# [val] chunk 62/89  sample 6171/8831
# [val] chunk 62/89  sample 6181/8831
# [val] chunk 62/89  sample 6191/8831
# ✅ saved: /content/graphs/val_chunk0061.pt (100 graphs)
# [val] chunk 63/89  sample 6201/8831
# [val] chunk 63/89  sample 6211/8831
# [val] chunk 63/89  sample 6221/8831
# [val] chunk 63/89  sample 6231/8831
# [val] chunk 63/89  sample 6241/8831
# [val] chunk 63/89  sample 6251/8831
# [val] chunk 63/89  sample 6261/8831
# [val] chunk 63/89  sample 6271/8831
# [val] chunk 63/89  sample 6281/8831
# [val] chunk 63/89  sample 6291/8831
# ✅ saved: /content/graphs/val_chunk0062.pt (100 graphs)
# [val] chunk 64/89  sample 6301/8831
# [val] chunk 64/89  sample 6311/8831
# [val] chunk 64/89  sample 6321/8831
# [val] chunk 64/89  sample 6331/8831
# [val] chunk 64/89  sample 6341/8831
# [val] chunk 64/89  sample 6351/8831
# [val] chunk 64/89  sample 6361/8831
# [val] chunk 64/89  sample 6371/8831
# [val] chunk 64/89  sample 6381/8831
# [val] chunk 64/89  sample 6391/8831
# ✅ saved: /content/graphs/val_chunk0063.pt (100 graphs)
# [val] chunk 65/89  sample 6401/8831
# [val] chunk 65/89  sample 6411/8831
# [val] chunk 65/89  sample 6421/8831
# [val] chunk 65/89  sample 6431/8831
# [val] chunk 65/89  sample 6441/8831
# [val] chunk 65/89  sample 6451/8831
# [val] chunk 65/89  sample 6461/8831
# [val] chunk 65/89  sample 6471/8831
# [val] chunk 65/89  sample 6481/8831
# [val] chunk 65/89  sample 6491/8831
# ✅ saved: /content/graphs/val_chunk0064.pt (100 graphs)
# [val] chunk 66/89  sample 6501/8831
# [val] chunk 66/89  sample 6511/8831
# [val] chunk 66/89  sample 6521/8831
# [val] chunk 66/89  sample 6531/8831
# [val] chunk 66/89  sample 6541/8831
# [val] chunk 66/89  sample 6551/8831
# [val] chunk 66/89  sample 6561/8831
# [val] chunk 66/89  sample 6571/8831
# [val] chunk 66/89  sample 6581/8831
# [val] chunk 66/89  sample 6591/8831
# ✅ saved: /content/graphs/val_chunk0065.pt (100 graphs)
# [val] chunk 67/89  sample 6601/8831
# [val] chunk 67/89  sample 6611/8831
# [val] chunk 67/89  sample 6621/8831
# [val] chunk 67/89  sample 6631/8831
# [val] chunk 67/89  sample 6641/8831
# [val] chunk 67/89  sample 6651/8831
# [val] chunk 67/89  sample 6661/8831
# [val] chunk 67/89  sample 6671/8831
# [val] chunk 67/89  sample 6681/8831
# [val] chunk 67/89  sample 6691/8831
# ✅ saved: /content/graphs/val_chunk0066.pt (100 graphs)
# [val] chunk 68/89  sample 6701/8831
# [val] chunk 68/89  sample 6711/8831
# [val] chunk 68/89  sample 6721/8831
# [val] chunk 68/89  sample 6731/8831
# [val] chunk 68/89  sample 6741/8831
# [val] chunk 68/89  sample 6751/8831
# [val] chunk 68/89  sample 6761/8831
# [val] chunk 68/89  sample 6771/8831
# [val] chunk 68/89  sample 6781/8831
# [val] chunk 68/89  sample 6791/8831
# ✅ saved: /content/graphs/val_chunk0067.pt (100 graphs)
# [val] chunk 69/89  sample 6801/8831
# [val] chunk 69/89  sample 6811/8831
# [val] chunk 69/89  sample 6821/8831
# [val] chunk 69/89  sample 6831/8831
# [val] chunk 69/89  sample 6841/8831
# [val] chunk 69/89  sample 6851/8831
# [val] chunk 69/89  sample 6861/8831
# [val] chunk 69/89  sample 6871/8831
# [val] chunk 69/89  sample 6881/8831
# [val] chunk 69/89  sample 6891/8831
# ✅ saved: /content/graphs/val_chunk0068.pt (100 graphs)
# [val] chunk 70/89  sample 6901/8831
# [val] chunk 70/89  sample 6911/8831
# [val] chunk 70/89  sample 6921/8831
# [val] chunk 70/89  sample 6931/8831
# [val] chunk 70/89  sample 6941/8831
# [val] chunk 70/89  sample 6951/8831
# [val] chunk 70/89  sample 6961/8831
# [val] chunk 70/89  sample 6971/8831
# [val] chunk 70/89  sample 6981/8831
# [val] chunk 70/89  sample 6991/8831
# ✅ saved: /content/graphs/val_chunk0069.pt (100 graphs)
# [val] chunk 71/89  sample 7001/8831
# [val] chunk 71/89  sample 7011/8831
# [val] chunk 71/89  sample 7021/8831
# [val] chunk 71/89  sample 7031/8831
# [val] chunk 71/89  sample 7041/8831
# [val] chunk 71/89  sample 7051/8831
# [val] chunk 71/89  sample 7061/8831
# [val] chunk 71/89  sample 7071/8831
# [val] chunk 71/89  sample 7081/8831
# [val] chunk 71/89  sample 7091/8831
# ✅ saved: /content/graphs/val_chunk0070.pt (100 graphs)
# [val] chunk 72/89  sample 7101/8831
# [val] chunk 72/89  sample 7111/8831
# [val] chunk 72/89  sample 7121/8831
# [val] chunk 72/89  sample 7131/8831
# [val] chunk 72/89  sample 7141/8831
# [val] chunk 72/89  sample 7151/8831
# [val] chunk 72/89  sample 7161/8831
# [val] chunk 72/89  sample 7171/8831
# [val] chunk 72/89  sample 7181/8831
# [val] chunk 72/89  sample 7191/8831
# ✅ saved: /content/graphs/val_chunk0071.pt (100 graphs)
# [val] chunk 73/89  sample 7201/8831
# [val] chunk 73/89  sample 7211/8831
# [val] chunk 73/89  sample 7221/8831
# [val] chunk 73/89  sample 7231/8831
# [val] chunk 73/89  sample 7241/8831
# [val] chunk 73/89  sample 7251/8831
# [val] chunk 73/89  sample 7261/8831
# [val] chunk 73/89  sample 7271/8831
# [val] chunk 73/89  sample 7281/8831
# [val] chunk 73/89  sample 7291/8831
# ✅ saved: /content/graphs/val_chunk0072.pt (100 graphs)
# [val] chunk 74/89  sample 7301/8831
# [val] chunk 74/89  sample 7311/8831
# [val] chunk 74/89  sample 7321/8831
# [val] chunk 74/89  sample 7331/8831
# [val] chunk 74/89  sample 7341/8831
# [val] chunk 74/89  sample 7351/8831
# [val] chunk 74/89  sample 7361/8831
# [val] chunk 74/89  sample 7371/8831
# [val] chunk 74/89  sample 7381/8831
# [val] chunk 74/89  sample 7391/8831
# ✅ saved: /content/graphs/val_chunk0073.pt (100 graphs)
# [val] chunk 75/89  sample 7401/8831
# [val] chunk 75/89  sample 7411/8831
# [val] chunk 75/89  sample 7421/8831
# [val] chunk 75/89  sample 7431/8831
# [val] chunk 75/89  sample 7441/8831
# [val] chunk 75/89  sample 7451/8831
# [val] chunk 75/89  sample 7461/8831
# [val] chunk 75/89  sample 7471/8831
# [val] chunk 75/89  sample 7481/8831
# [val] chunk 75/89  sample 7491/8831
# ✅ saved: /content/graphs/val_chunk0074.pt (100 graphs)
# [val] chunk 76/89  sample 7501/8831
# [val] chunk 76/89  sample 7511/8831
# [val] chunk 76/89  sample 7521/8831
# [val] chunk 76/89  sample 7531/8831
# [val] chunk 76/89  sample 7541/8831
# [val] chunk 76/89  sample 7551/8831
# [val] chunk 76/89  sample 7561/8831
# [val] chunk 76/89  sample 7571/8831
# [val] chunk 76/89  sample 7581/8831
# [val] chunk 76/89  sample 7591/8831
# ✅ saved: /content/graphs/val_chunk0075.pt (100 graphs)
# [val] chunk 77/89  sample 7601/8831
# [val] chunk 77/89  sample 7611/8831
# [val] chunk 77/89  sample 7621/8831
# [val] chunk 77/89  sample 7631/8831
# [val] chunk 77/89  sample 7641/8831
# [val] chunk 77/89  sample 7651/8831
# [val] chunk 77/89  sample 7661/8831
# [val] chunk 77/89  sample 7671/8831
# [val] chunk 77/89  sample 7681/8831
# [val] chunk 77/89  sample 7691/8831
# ✅ saved: /content/graphs/val_chunk0076.pt (100 graphs)
# [val] chunk 78/89  sample 7701/8831
# [val] chunk 78/89  sample 7711/8831
# [val] chunk 78/89  sample 7721/8831
# [val] chunk 78/89  sample 7731/8831
# [val] chunk 78/89  sample 7741/8831
# [val] chunk 78/89  sample 7751/8831
# [val] chunk 78/89  sample 7761/8831
# [val] chunk 78/89  sample 7771/8831
# [val] chunk 78/89  sample 7781/8831
# [val] chunk 78/89  sample 7791/8831
# ✅ saved: /content/graphs/val_chunk0077.pt (100 graphs)
# [val] chunk 79/89  sample 7801/8831
# [val] chunk 79/89  sample 7811/8831
# [val] chunk 79/89  sample 7821/8831
# [val] chunk 79/89  sample 7831/8831
# [val] chunk 79/89  sample 7841/8831
# [val] chunk 79/89  sample 7851/8831
# [val] chunk 79/89  sample 7861/8831
# [val] chunk 79/89  sample 7871/8831
# [val] chunk 79/89  sample 7881/8831
# [val] chunk 79/89  sample 7891/8831
# ✅ saved: /content/graphs/val_chunk0078.pt (100 graphs)
# [val] chunk 80/89  sample 7901/8831
# [val] chunk 80/89  sample 7911/8831
# [val] chunk 80/89  sample 7921/8831
# [val] chunk 80/89  sample 7931/8831
# [val] chunk 80/89  sample 7941/8831
# [val] chunk 80/89  sample 7951/8831
# [val] chunk 80/89  sample 7961/8831
# [val] chunk 80/89  sample 7971/8831
# [val] chunk 80/89  sample 7981/8831
# [val] chunk 80/89  sample 7991/8831
# ✅ saved: /content/graphs/val_chunk0079.pt (100 graphs)
# [val] chunk 81/89  sample 8001/8831
# [val] chunk 81/89  sample 8011/8831
# [val] chunk 81/89  sample 8021/8831
# [val] chunk 81/89  sample 8031/8831
# [val] chunk 81/89  sample 8041/8831
# [val] chunk 81/89  sample 8051/8831
# [val] chunk 81/89  sample 8061/8831
# [val] chunk 81/89  sample 8071/8831
# [val] chunk 81/89  sample 8081/8831
# [val] chunk 81/89  sample 8091/8831
# ✅ saved: /content/graphs/val_chunk0080.pt (100 graphs)
# [val] chunk 82/89  sample 8101/8831
# [val] chunk 82/89  sample 8111/8831
# [val] chunk 82/89  sample 8121/8831
# [val] chunk 82/89  sample 8131/8831
# [val] chunk 82/89  sample 8141/8831
# [val] chunk 82/89  sample 8151/8831
# [val] chunk 82/89  sample 8161/8831
# [val] chunk 82/89  sample 8171/8831
# [val] chunk 82/89  sample 8181/8831
# [val] chunk 82/89  sample 8191/8831
# ✅ saved: /content/graphs/val_chunk0081.pt (100 graphs)
# [val] chunk 83/89  sample 8201/8831
# [val] chunk 83/89  sample 8211/8831
# [val] chunk 83/89  sample 8221/8831
# [val] chunk 83/89  sample 8231/8831
# [val] chunk 83/89  sample 8241/8831
# [val] chunk 83/89  sample 8251/8831
# [val] chunk 83/89  sample 8261/8831
# [val] chunk 83/89  sample 8271/8831
# [val] chunk 83/89  sample 8281/8831
# [val] chunk 83/89  sample 8291/8831
# ✅ saved: /content/graphs/val_chunk0082.pt (100 graphs)
# [val] chunk 84/89  sample 8301/8831
# [val] chunk 84/89  sample 8311/8831
# [val] chunk 84/89  sample 8321/8831
# [val] chunk 84/89  sample 8331/8831
# [val] chunk 84/89  sample 8341/8831
# [val] chunk 84/89  sample 8351/8831
# [val] chunk 84/89  sample 8361/8831
# [val] chunk 84/89  sample 8371/8831
# [val] chunk 84/89  sample 8381/8831
# [val] chunk 84/89  sample 8391/8831
# ✅ saved: /content/graphs/val_chunk0083.pt (100 graphs)
# [val] chunk 85/89  sample 8401/8831
# [val] chunk 85/89  sample 8411/8831
# [val] chunk 85/89  sample 8421/8831
# [val] chunk 85/89  sample 8431/8831
# [val] chunk 85/89  sample 8441/8831
# [val] chunk 85/89  sample 8451/8831
# [val] chunk 85/89  sample 8461/8831
# [val] chunk 85/89  sample 8471/8831
# [val] chunk 85/89  sample 8481/8831
# [val] chunk 85/89  sample 8491/8831
# ✅ saved: /content/graphs/val_chunk0084.pt (100 graphs)
# [val] chunk 86/89  sample 8501/8831
# [val] chunk 86/89  sample 8511/8831
# [val] chunk 86/89  sample 8521/8831
# [val] chunk 86/89  sample 8531/8831
# [val] chunk 86/89  sample 8541/8831
# [val] chunk 86/89  sample 8551/8831
# [val] chunk 86/89  sample 8561/8831
# [val] chunk 86/89  sample 8571/8831
# [val] chunk 86/89  sample 8581/8831
# [val] chunk 86/89  sample 8591/8831
# ✅ saved: /content/graphs/val_chunk0085.pt (100 graphs)
# [val] chunk 87/89  sample 8601/8831
# [val] chunk 87/89  sample 8611/8831
# [val] chunk 87/89  sample 8621/8831
# [val] chunk 87/89  sample 8631/8831
# [val] chunk 87/89  sample 8641/8831
# [val] chunk 87/89  sample 8651/8831
# [val] chunk 87/89  sample 8661/8831
# [val] chunk 87/89  sample 8671/8831
# [val] chunk 87/89  sample 8681/8831
# [val] chunk 87/89  sample 8691/8831
# ✅ saved: /content/graphs/val_chunk0086.pt (100 graphs)
# [val] chunk 88/89  sample 8701/8831
# [val] chunk 88/89  sample 8711/8831
# [val] chunk 88/89  sample 8721/8831
# [val] chunk 88/89  sample 8731/8831
# [val] chunk 88/89  sample 8741/8831
# [val] chunk 88/89  sample 8751/8831
# [val] chunk 88/89  sample 8761/8831
# [val] chunk 88/89  sample 8771/8831
# [val] chunk 88/89  sample 8781/8831
# [val] chunk 88/89  sample 8791/8831
# ✅ saved: /content/graphs/val_chunk0087.pt (100 graphs)
# [val] chunk 89/89  sample 8801/8831
# [val] chunk 89/89  sample 8811/8831
# [val] chunk 89/89  sample 8821/8831
# [val] chunk 89/89  sample 8831/8831
# ✅ saved: /content/graphs/val_chunk0088.pt (31 graphs)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

train_dataset = torch.load("/content/graphs/train_chunk*.pt")
val_dataset   = torch.load("/content/graphs/val_chunk*.pt")

train_loader = GraphDataLoader(train_dataset, batch_size=8, shuffle=True, num_workers=0)
val_loader   = GraphDataLoader(val_dataset, batch_size=8, shuffle=False, num_workers=0)

model = ProteinGNN(input_dim=1280).to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-5)

best_val_acc = 0
EPOCHS = 20

print("\n=== Training GNN (no ESM during training) ===")
for epoch in range(EPOCHS):
    model.train()
    train_loss, train_correct, train_total = 0, 0, 0

    pbar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{EPOCHS}")
    for batch in pbar:
        batch = batch.to(device)
        optimizer.zero_grad()

        logits, _ = model(batch.x, batch.edge_index, batch.batch)
        loss = F.cross_entropy(logits, batch.y)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()

        train_loss += loss.item()
        pred = logits.argmax(1)
        train_correct += (pred == batch.y).sum().item()
        train_total += batch.num_graphs

        pbar.set_postfix(loss=train_loss/max(1, len(train_loader)),
                        acc=train_correct/max(1, train_total))

    val_acc = evaluate(model, val_loader, device)
    print(f"Epoch {epoch+1:2d}: TrainLoss {train_loss/len(train_loader):.4f}, "
          f"TrainAcc {train_correct/train_total:.4f}, ValAcc {val_acc:.4f}")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), "/content/best_esm_gnn.pth")
        print("✅ saved best model")

print(f"\nBest Val Acc: {best_val_acc:.4f}")
print("Model saved: /content/best_esm_gnn.pth")
